# %% [markdown]
# # Cloud Function to Beam Pipeline
#
# In this example we'll be converting a series of Cloud Functions to an Apache Beam pipeline.
#
# ### Background
#
# Your team receives invoice data from your ordering system in JSON format. Currently, the data is processed by a series of Cloud Functions.
#
#
# The JSON object contains a list of invoices and each invoice has the following structure:
# ```json
# {
#   "invoice_id": int,
#   "customer_id": int,
#   "line_items": [
#     {
#       "line_no": int,
#       "product_name": str,
#       "quantity": int,
#       "price_ea": float
#     }
#   ]
# }
# ```
#
# ### Create the Sample Data
#
# The cell below contains a function that generates sample data, let's run it to generate some records for us to test our pipeline.

# %%
import random
import json

def generate_sample_data(n_records: int = 100, n_customers: int = 10) -> list[str]:
    """
    params:
        n_records (int): The number of sample records to create. Default = 100
        n_customers (int): The number of unique customer_ids to include. Default = 10
    
    out:
        sample invoices (list[str]): a list of sample records formatted as JSON strings
    """
    # products and their corresponding prices
    products = ['Scissors', 'Tape', 'Printer Paper', 'Box', 'Envelope']
    prices = [9.99, 0.99, 7.99, 2.49, 1.49]
    
    # initialize variables
    invoice_no = 0
    invoices = []
    
    while len(invoices) < n_records:
        # generate a random customer ID
        customer_id = random.randint(1, n_customers)
        
        # each product gets its own line item on the invoice
        line_items = []
        for price, product in zip(prices, products):
            # get a random quantity for each product
            quantity = random.randint(0, 5)
            # if quantity is zero, skip that line
            if quantity <= 0:
                continue
            
            line_items.append(
                {'line_no': len(line_items) + 1, 'product_name': product, 'quantity': quantity, 'price_ea': price}
            )
        
        if line_items:
            invoice_no += 1
            invoices.append(
                json.dumps({'invoice_id': invoice_no, 'customer_id': customer_id, 'line_items': line_items}, indent=2)
            )
    
    return invoices

sample_data = generate_sample_data()

# %% [markdown]
# ### Review the Data
#
# Let's check out the sample data. Run the cell below to see what one record of the sample data looks like.

# %%
print(sample_data[0])
# Out:
# {
#   "invoice_id": 1,
#   "customer_id": 3,
#   "line_items": [
#     {
#       "line_no": 1,
#       "product_name": "Scissors",
#       "quantity": 3,
#       "price_ea": 9.99
#     },
#     {
#       "line_no": 2,
#       "product_name": "Tape",
#       "quantity": 4,
#       "price_ea": 0.99
#     },
#     {
#       "line_no": 3,
#       "product_name": "Printer Paper",
#       "quantity": 5,
#       "price_ea": 7.99
#     },
#     {
#       "line_no": 4,
#       "product_name": "Box",
#       "quantity": 1,
#       "price_ea": 2.49
#     },
#     {
#       "line_no": 5,
#       "product_name": "Envelope",
#       "quantity": 4,
#       "price_ea": 1.49
#     }
#   ]
# }

# %% [markdown]
# ### Cloud Functions
#
# Your company decided to use a series of Cloud Functions as its ETL solution because there are multiple stages and each stage's output needs to be used by multiple downstream stages. Instead of creating one massive pipeline, to make it easier to maintain and update you decided to break each stage out into its own Cloud Function.

# %%
# Cloud Function 1
def get_total_by_invoice(invoice_list: list):
    invoice_totals = []
    for invoice_json in invoice_list:
        invoice = json.loads(invoice_json)
        line_items = invoice.get('line_items', [])
        
        if not line_items:
            continue
        
        running_total = 0.00
        for line_item in line_items:
            quantity = line_item.get('quantity', 0)
            price_ea = line_item.get('price_ea', 0.00)
            running_total += quantity * price_ea
    
        invoice_totals.append(
            json.dumps({'invoice_id': element.get('invoice_id', None), 'invoice_total': round(running_total, 2)})
        )
    
    return invoice_totals
            
# Cloud Function 2
def get_total_by_customer(invoice_list: list):
    customer_totals = {}
    for invoice_json in invoice_list:
        invoice = json.loads(invoice_json)
        customer_id = invoice.get('customer_id', -1)
        line_items = invoice.get('line_items', [])
        
        if not (line_items and customer_id >= 0):
            continue
        
        running_total = 0.00
        for line_item in line_items:
            quantity = line_item.get('quantity', 0)
            price_ea = line_item.get('price_ea', 0.00)
            running_total += quantity * price_ea
    
        customer_total = customer_totals.get(customer_id, 0.00)
        customer_totals[customer_id] = customer_total + running_total
    
    return customer_totals

# %%
import apache_beam as beam
from apache_beam import Create, Map, GroupByKey, FlatMap
from apache_beam.transforms.util import WithKeys

from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

# %%
p = beam.Pipeline(InteractiveRunner())

invoices = (p | 'Create Invoice PColl' >> Create(sample_data)
              | 'Convert JSON to PColl' >> Map(json.loads))

ib.show(invoices)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_54052fccc29d7a45d36e6fed8682cd46">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_5d9619bb5c6cf9c22cccf2bfe3297729" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_5d9619bb5c6cf9c22cccf2bfe3297729")) {
#               dt = $("#table_df_5d9619bb5c6cf9c22cccf2bfe3297729").dataTable();
#             } else if ($("#table_df_5d9619bb5c6cf9c22cccf2bfe3297729_wrapper").length == 0) {
#               dt = $("#table_df_5d9619bb5c6cf9c22cccf2bfe3297729").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'invoice_id'}, {'title': 'customer_id'}, {'title': 'line_items'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '1', 2: '3', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 3, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}, {'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}]", 0: 0}, {1: '2', 2: '8', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 3, 'price_ea': 2.49}, {'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}]", 0: 1}, {1: '3', 2: '1', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Envelope', 'quantity': 5, 'price_ea': 1.49}]", 0: 2}, {1: '4', 2: '3', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 3, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 1, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 2, 'price_ea': 2.49}, {'line_no': 5, 'product_name': 'Envelope', 'quantity': 3, 'price_ea': 1.49}]", 0: 3}, {1: '5', 2: '9', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}, {'line_no': 5, 'product_name': 'Envelope', 'quantity': 5, 'price_ea': 1.49}]", 0: 4}, {1: '6', 2: '8', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Box', 'quantity': 5, 'price_ea': 2.49}, {'line_no': 3, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}]", 0: 5}, {1: '7', 2: '4', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 3, 'price_ea': 2.49}, {'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}]", 0: 6}, {1: '8', 2: '3', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 2, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 4, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 5, 'price_ea': 2.49}]", 0: 7}, {1: '9', 2: '6', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Tape', 'quantity': 3, 'price_ea': 0.99}, {'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}, {'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}]", 0: 8}, {1: '10', 2: '7', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 2, 'price_ea': 9.99}, {'line_no': 2, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}, {'line_no': 3, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}]", 0: 9}, {1: '11', 2: '7', 3: "[{'line_no': 1, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}, {'line_no': 2, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}, {'line_no': 3, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}, {'line_no': 4, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}]", 0: 10}, {1: '12', 2: '3', 3: "[{'line_no': 1, 'product_name': 'Scissors', 'quantity': 3, 'price_ea': 9.99}, {'line_no': 2, 'product_name': ...

# %%
def get_invoice_totals(element):
    line_items = element.get('line_items', [])
    
    running_total = 0.00
    for line_item in line_items:
        quantity = line_item.get('quantity', 0)
        price_ea = line_item.get('price_ea', 0.00)
        running_total += quantity * price_ea
    return {'invoice_id': element.get('invoice_id', None), 'invoice_total': round(running_total, 2)}

invoice_totals = invoices | 'Get Invoice Total Amount' >> Map(get_invoice_totals)

ib.show(invoice_totals)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_6e1d758643187ed2ee40c3134501e47c">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_007f459b662904d6cea2528f8324e037" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_007f459b662904d6cea2528f8324e037")) {
#               dt = $("#table_df_007f459b662904d6cea2528f8324e037").dataTable();
#             } else if ($("#table_df_007f459b662904d6cea2528f8324e037_wrapper").length == 0) {
#               dt = $("#table_df_007f459b662904d6cea2528f8324e037").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'invoice_id'}, {'title': 'invoice_total'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '1',
# %%
def get_customer_totals(element):
    line_items = element.get('line_items', [])
    customer_id = element.get('customer_id', None)
    
    running_total = 0.00
    for line_item in line_items:
        quantity = line_item.get('quantity', 0)
        price_ea = line_item.get('price_ea', 0.00)
        running_total += quantity * price_ea
    
    return [customer_id, round(running_total, 2)]

customer_invoice_totals = (invoices | 'Get Total For Each Invoice' >> Map(get_customer_totals)
                                    | 'Group By Customer ID' >> GroupByKey())

ib.show(customer_invoice_totals)

# # TODO: Get the total amount spent per customer

# total_per_customer = customer_invoice_totals | 'Get Total Spent per Customer' >> # DoSomething

# ib.show(total_per_customer)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_0e239ddbc1601f4e24d6e3cfece08fdf">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_8bd1bf111e06aee2ba6fb00db146c145" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8bd1bf111e06aee2ba6fb00db146c145")) {
#               dt = $("#table_df_8bd1bf111e06aee2ba6fb00db146c145").dataTable();
#             } else if ($("#table_df_8bd1bf111e06aee2ba6fb00db146c145_wrapper").length == 0) {
#               dt = $("#table_df_8bd1bf111e06aee2ba6fb00db146c145").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'customer_invoice_totals.0'}, {'title': 'customer_invoice_totals.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '3', 2: '[82.33, 30.4, 66.37, 83.83, 36.91, 39.9, 82.34, 47.36, 69.86, 39.34, 41.93, 104.8]', 0: 0}, {1: '8', 2: '[105.31, 68.36, 40.89, 90.85, 32.92, 11.42, 99.82, 54.88, 40.9, 42.42, 15.46, 35.92, 72.82]', 0: 1}, {1: '1', 2: '[21.4, 40.4, 96.34, 52.37, 20.44, 51.88, 65.86, 10.45, 35.43, 51.88, 65.39, 103.3, 67.85, 62.36]', 0: 2}, {1: '9', 2: '[47.86, 37.41, 62.41, 84.85]', 0: 3}, {1: '4', 2: '[89.33, 58.83, 22.44, 71.35, 72.38, 29.92, 84.34, 57.42, 58.89, 46.93]', 0: 4}, {1: '6', 2: '[55.4, 44.4, 78.35, 25.97, 40.38, 49.41, 25.9]', 0: 5}, {1: '7', 2: '[46.44, 36.38, 29.87, 76.33, 98.29, 61.91]', 0: 6}, {1: '10', 2: '[63.39, 52.87, 62.86, 44.37, 66.87, 27.41, 35.91, 62.88, 97.32, 20.93, 8.45, 80.81, 44.87, 87.36, 82.35, 82.34, 75.88, 43.89, 55.89, 100.8]', 0: 7}, {1: '2', 2: '[61.88, 87.86, 71.35, 26.89, 64.39]', 0: 8}, {1: '5', 2: '[54.36, 34.89, 59.34, 74.82, 67.33, 79.35, 43.84, 78.9, 89.79]', 0: 9}])
#               .draw('full-hold');
#               });
#             }
#             document.head.appendChild(datatableScript);
#           };
#           document.head.appendChild(jqueryScript);
#         } else {
#           window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8bd1bf111e06aee2ba6fb00db146c145")) {
#               dt = $("#table_df_8bd1bf111e06aee2ba6fb00db146c145").dataTable();
#             } else if ($("#table_df_8bd1bf111e06aee2ba6fb00db146c145_wrapper").length == 0) {
#               dt = $("#table_df_8bd1bf111e06aee2ba6fb00db146c145").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'customer_invoice_totals.0'}, {'title': 'customer_invoice_totals.1'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: '3', 2: '[82.33, 30.4, 66.37, 83.83, 36.91, 39.9, 82.34, 47.36, 69.86, 39.34, 41.93, 104.8]', 0: 0}, {1: '8', 2: '[105.31, 68.36, 40.89, 90.85, 32.92, 11.42, 99.82, 54.88, 40.9, 42.42, 15.46, 35.92, 72.82]', 0: 1}, {1: '1', 2: '[21.4, 40.4, 96.34, 52.37, 20.44, 51.88, 65.86, 10.45, 35.43, 51.88, 65.39, 103.3, 67.85, 62.36]', 0: 2}, {1: '9', 2: '[47.86, 37.41, 62.41, 84.85]', 0: 3}, {1: '4', 2: '[89.33, 58.83, 22.44, 71.35, 72.38, 29.92, 84.34, 57.42, 58.89, 46.93]', 0: 4}, {1: '6', 2: '[55.4, 44.4, 78.35, 25.97, 40.38, 49.41, 25.9]', 0: 5}, {1: '7', 2: '[46.44, 36.38, 29.87, 76.33, 98.29, 61.91]', 0: 6}, {1: '10', 2: '[63.39, 52.87, 62.86, 44.37, 66.87, 27.41, 35.91, 62.88, 97.32, 20.93, 8.45, 80.81, 44.87, 87.36, 82.35, 82.34, 75.88, 43.89, 55.89, 100.8]', 0: 7}, {1: '2', 2: '[61.88, 87.86, 71.35, 26.89, 64.39]', 0: 8}, {1: '5', 2: '[54.36, 34.89, 59.34, 74.82, 67.33, 79.35, 43.84, 78.9, 89.79]', 0: 9}])
#               .draw('full-hold');
#           });
#         }
#             </script>

# %%
products = invoices | Map(lambda x: x.get('line_items', []))

ib.show(products)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_9ce41d40a78e919ebd450d654277b8a7">
#               <div class="spinner-border text-info" role="status"></div>
#               <span class="text-info">Processing... show</span>
#             </div>
#             <style>
#             .p-Widget.jp-OutputPrompt.jp-OutputArea-prompt:empty {
#               padding: 0;
#               border: 0;
#             }
#             .p-Widget.jp-RenderedJavaScript.jp-mod-trusted.jp-OutputArea-output:empty {
#               padding: 0;
#               border: 0;
#             }
#             </style>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <table id="table_df_8073bcb94bc5f3ad5680fd31a537042d" class="display" style="display:block"></table>
#             <script>
#
#         if (typeof window.interactive_beam_jquery == 'undefined') {
#           var jqueryScript = document.createElement('script');
#           jqueryScript.src = 'https://code.jquery.com/jquery-3.4.1.slim.min.js';
#           jqueryScript.type = 'text/javascript';
#           jqueryScript.onload = function() {
#             var datatableScript = document.createElement('script');
#             datatableScript.src = 'https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js';
#             datatableScript.type = 'text/javascript';
#             datatableScript.onload = function() {
#               window.interactive_beam_jquery = jQuery.noConflict(true);
#               window.interactive_beam_jquery(document).ready(function($){
#
#             var dt;
#             if ($.fn.dataTable.isDataTable("#table_df_8073bcb94bc5f3ad5680fd31a537042d")) {
#               dt = $("#table_df_8073bcb94bc5f3ad5680fd31a537042d").dataTable();
#             } else if ($("#table_df_8073bcb94bc5f3ad5680fd31a537042d_wrapper").length == 0) {
#               dt = $("#table_df_8073bcb94bc5f3ad5680fd31a537042d").dataTable({
#
#             bAutoWidth: false,
#             columns: [{'title': ''}, {'title': 'products.0'}, {'title': 'products.1'}, {'title': 'products.2'}, {'title': 'products.3'}, {'title': 'products.4'}],
#             destroy: true,
#             responsive: true,
#             columnDefs: [
#               {
#                 targets: "_all",
#                 className: "dt-left"
#               },
#               {
#                 "targets": 0,
#                 "width": "10px",
#                 "title": ""
#               }
#             ]
#               });
#             } else {
#               return;
#             }
#             dt.api()
#               .clear()
#               .rows.add([{1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 3, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}", 5: "{'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}", 0: 0}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 3, 'price_ea': 2.49}", 5: "{'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}", 0: 1}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Envelope', 'quantity': 5, 'price_ea': 1.49}", 4: 'None', 5: 'None', 0: 2}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 3, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 1, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 2, 'price_ea': 2.49}", 5: "{'line_no': 5, 'product_name': 'Envelope', 'quantity': 3, 'price_ea': 1.49}", 0: 3}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}", 5: "{'line_no': 5, 'product_name': 'Envelope', 'quantity': 5, 'price_ea': 1.49}", 0: 4}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Box', 'quantity': 5, 'price_ea': 2.49}", 3: "{'line_no': 3, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}", 4: 'None', 5: 'None', 0: 5}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 5, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 3, 'price_ea': 2.49}", 5: "{'line_no': 5, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}", 0: 6}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 2, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 2, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 4, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 5, 'price_ea': 2.49}", 5: 'None', 0: 7}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 1, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Tape', 'quantity': 3, 'price_ea': 0.99}", 3: "{'line_no': 3, 'product_name': 'Printer Paper', 'quantity': 5, 'price_ea': 7.99}", 4: "{'line_no': 4, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}", 5: 'None', 0: 8}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantity': 2, 'price_ea': 9.99}", 2: "{'line_no': 2, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}", 3: "{'line_no': 3, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}", 4: 'None', 5: 'None', 0: 9}, {1: "{'line_no': 1, 'product_name': 'Tape', 'quantity': 4, 'price_ea': 0.99}", 2: "{'line_no': 2, 'product_name': 'Printer Paper', 'quantity': 3, 'price_ea': 7.99}", 3: "{'line_no': 3, 'product_name': 'Box', 'quantity': 1, 'price_ea': 2.49}", 4: "{'line_no': 4, 'product_name': 'Envelope', 'quantity': 4, 'price_ea': 1.49}", 5: 'None', 0: 10}, {1: "{'line_no': 1, 'product_name': 'Scissors', 'quantit ...
